# %%
library(ggplot2)
library(LaplacesDemon)

# %%
x <-  seq(-5, 5, length=100)

location <- 0
scale <- 1

fx <- dlaplace(x, location = location, scale = scale)

data <-data.frame(x=x,y=fx)
ggplot(data, aes(x=x,y=fx)) + geom_line()
