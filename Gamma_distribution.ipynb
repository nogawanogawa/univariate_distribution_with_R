# %%
library(ggplot2)

# %%
x <-  seq(0, 15, length=100)

alpha <- 2
beta <- 1

fx <- dgamma(x, shape=beta, scale = alpha , log = FALSE)

data <-data.frame(x=x,y=fx)
ggplot(data, aes(x=x,y=fx)) + geom_line()
