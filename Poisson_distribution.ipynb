# %%
n <- 10 # 試行回数

# mu : 平均何回起こるか
plot(dpois(0:n, 0), type="o", xlab="x",  xaxt="n", ylab="probability", main="Poisson distribution")
axis(side=1, at=1:10, labels=F)
for(mu in 1:n) { 
  points(dpois(0:n, mu), col=mu)
  lines(dpois(0:n, mu), col=mu)
}

grid()
